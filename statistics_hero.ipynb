# %%
import requests
from prettytable import PrettyTable
from typing import Dict, Optional, List

# %% [markdown]
# ## hero winrate and counter

# %%
class FilterAPI:
    def __init__(self, url: str, payload: Dict):
        self.url = url
        self.payload = payload

    def fetch_data(self) -> Optional[Dict]:
        try:
            response = requests.post(self.url, json=self.payload)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            print(f"An error occurred: {e}")
            return None

class FilterFactory:
    URLS = {
        "1": "https://api.gms.moontontech.com/api/gms/source/2669606/2690817",
        "3": "https://api.gms.moontontech.com/api/gms/source/2669606/2690816",
        "7": "https://api.gms.moontontech.com/api/gms/source/2669606/2690519",
        "15": "https://api.gms.moontontech.com/api/gms/source/2669606/2674707",
        "30": "https://api.gms.moontontech.com/api/gms/source/2669606/2690818",
    }

    RANKS = {
        "glory": {"field": "bigrank", "operator": "eq", "value": "9"},
        "honor": {"field": "bigrank", "operator": "eq", "value": "8"},
        "mythic": {"field": "bigrank", "operator": "eq", "value": "7"},
        "legend": {"field": "bigrank", "operator": "eq", "value": "6"},
        "epic": {"field": "bigrank", "operator": "eq", "value": "5"},
        "all": {"field": "bigrank", "operator": "eq", "value": "101"},
    }

    @staticmethod
    def create_filter(day_filter: str, rank_filter: str, page_size: int, page_index: int, sorts_field: str, sorts_order: str) -> Optional[FilterAPI]:
        """
        Create a FilterAPI object based on the provided filter parameters.
        Args:
          day_filter: 1 day, 3 days, 7 days, 15 days, 30 days
          rank_filter: all, epic, legend, mythic, honor, glory
          page_size: 1 - 125
          page_index: 1 - 125
          sorts_field: main_hero_appearance_rate, main_hero_win_rate, main_hero_ban_rate
          sorts_order: asc, desc

        Returns:
          FilterAPI object or None if invalid filter type.
        """
        url = FilterFactory.URLS.get(day_filter)
        rank = FilterFactory.RANKS.get(rank_filter)

        if not url or not rank:
            print("Invalid day or rank filter.")
            return None

        payload = {
            "pageSize": page_size,
            "filters": [
                rank,
                {"field": "match_type", "operator": "eq", "value": "0"}
            ],
            "sorts": [
                {"data": {"field": sorts_field, "order": sorts_order}, "type": "sequence"},
                {"data": {"field": "main_heroid", "order": "desc"}, "type": "sequence"}
            ],
            "pageIndex": page_index,
            "fields": [
                "main_hero", "main_hero_appearance_rate", "main_hero_ban_rate",
                "main_hero_channel", "main_hero_win_rate", "main_heroid",
                "data.sub_hero.hero", "data.sub_hero.hero_channel",
                "data.sub_hero.increase_win_rate", "data.sub_hero.heroid"
            ]
        }

        return FilterAPI(url=url, payload=payload)

def create_hero_table(data: Dict, rate_filter: Optional[Dict[str, float]] = None) -> PrettyTable:
    table = PrettyTable()
    table.field_names = [
        "Hero ID",
        "Hero Name",
        # "Image URL",
        "Pick Rate",
        "Win Rate",
        "Ban Rate",
        "Counter Hero"
    ]
    table.align["Hero ID"] = "r"
    table.align["Hero Name"] = "l"
    table.align["Ban Rate"] = "r"
    table.right_padding_width = 1

    hero_name_dict = {record['data']['main_heroid']: record['data']['main_hero']['data']['name']
                      for record in data['data']['records']}

    for record in data['data']['records']:
        hero_data = record['data']['main_hero']['data']
        pick_rate = record['data']['main_hero_appearance_rate']
        win_rate = record['data']['main_hero_win_rate']
        ban_rate = record['data']['main_hero_ban_rate']

        # Apply the filter if specified
        if rate_filter:
            if "pick_rate" in rate_filter and pick_rate < rate_filter["pick_rate"]:
                continue
            if "win_rate" in rate_filter and win_rate < rate_filter["win_rate"]:
                continue
            if "ban_rate" in rate_filter and ban_rate < rate_filter["ban_rate"]:
                continue

        counter_hero_names = [hero_name_dict.get(hero['heroid'], "Unknown")
                              for hero in record['data']['sub_hero']]

        table.add_row([
            record['data']['main_heroid'],
            hero_data['name'],
            # hero_data['head'],
            f"{pick_rate:.2%}",
            f"{win_rate:.2%}",
            f"{ban_rate:.2%}",
            ','.join(counter_hero_names)
        ])

    return table

# %%
def main():
    day_filter               = "1" # 1 day, 3 days, 7 days, 15 days, 30 days
    rank_filter              = "glory" # all, epic, legend, mythic, honor, glory
    page_size                = 125
    page_index               = 1
    type_rate, rate          = "win_rate", 0
    sorts_field, sorts_order = "main_hero_win_rate", "desc"


    filter_factory = FilterFactory.create_filter(day_filter, rank_filter, page_size, page_index, sorts_field, sorts_order)

    if filter_factory:
        data = filter_factory.fetch_data()
        if data:
            table = create_hero_table(data, {type_rate: rate})
            print(table)
        else:
            print("Failed to retrieve data.")
    else:
        print("Invalid filter type.")

if __name__ == "__main__":
    main()
# Out:
# +---------+----------------+-----------+----------+----------+---------------------------------------------+
# | Hero ID | Hero Name      | Pick Rate | Win Rate | Ban Rate |                 Counter Hero                |
# +---------+----------------+-----------+----------+----------+---------------------------------------------+
# |      20 | Lolita         |   0.67%   |  63.97%  |    8.79% |      Cyclops,Floryn,Bruno,Aamon,Granger     |
# |      49 | Hylos          |   1.67%   |  57.12%  |   76.90% |      Eudora,Miya,Zilong,Gatotkaca,Layla     |
# |      50 | Zhask          |   1.52%   |  56.45%  |   82.90% |       Harley,Wanwan,Selena,Arlott,Yin       |
# |      48 | Diggie         |   0.51%   |  56.12%  |   12.61% |      Guinevere,Gloo,Cici,Alpha,Fredrinn     |
# |     125 | Zhuxin         |   0.74%   |  56.02%  |   93.08% |       Baxia,Lolita,Hanabi,Alice,Martis      |
# |     111 | Edith          |   1.31%   |  55.62%  |    2.12% |      Joy,Kadita,Fredrinn,Hilda,Cyclops      |
# |      11 | Bane           |   1.37%   |  55.03%  |    1.40% |     Balmond,Khufra,Baxia,Faramis,Aldous     |
# |     124 | Chip           |   0.48%   |  54.57%  |   35.42% |       Aulus,Hayabusa,Akai,Atlas,Selena      |
# |      22 | Freya          |   0.77%   |  54.52%  |   19.82% |     Diggie,Lolita,Aulus,X.Borg,Mathilda     |
# |      94 | Popol and Kupa |   0.87%   |  54.49%  |    8.22% |     Harley,Aldous,Silvanna,Zilong,Selena    |
# |     112 | Floryn         |   1.00%   |  54.47%  |    9.77% |     Balmond,X.Borg,Belerick,Chip,Lesley     |
# |      88 | Masha          |   0.20%   |  53.67%  |    0.23% |      Zilong,Rafaela,Wanwan,Zhuxin,Baxia     |
# |      36 | Aurora         |   1.43%   |  53.65%  |    1.06% |        Lolita,Odette,Estes,Miya,Baxia       |
# |      29 | Ruby           |   2.83%   |  53.59%  |   39.00% |         Sun,Silvanna,Gloo,Masha,Joy         |
# |      82 | Terizla        |   3.05%   |  53.56%  |   36.80% |   Badang,Argus,Popol and Kupa,Sun,Fredrinn  |
# |      45 | Argus          |   0.54%   |  53.11%  |    1.40% |      Saber,Masha,Yve,Minsitthar,Xavier      |
# |      76 | Faramis        |   0.36%   |  53.09%  |    0.30% |        Gloo,Sun,Harley,Argus,Cyclops        |
# |      30 | Yi Sun-shin    |   0.57%   |  53.08%  |    0.18% |       Baxia,Badang,Akai,Vale,Benedetta      |
# |      73 | Harith         |   0.61%   |  52.60%  |    0.35% |      Uranus,Pharsa,Silvanna,Atlas,Vale      |
# |     121 | Ixia           |   1.16%   |  52.42%  |    1.91% |      Estes,Badang,Hanabi,Rafaela,Thamuz     |
# |      41 | Gatotkaca      |   1.72%   |  52.12%  |    5.13% |        Badang,Freya,Miya,Saber,Hanabi       |
# |      38 | Vexana         |   2.03%   |  52.11%  |    1.17% |     Gloo,Fredrinn,Phoveus,Zhask,Alucard     |
# |       1 | Miya           |   0.83%   |  51.97%  |    0.43% |     Diggie,Saber,Mathilda,Rafaela,Harith    |
# |      55 | Angela         |   1.91%   |  51.94%  |    9.88% |    Alice,Yve,Yi Sun-shin,Novaria,Lancelot   |
# |      98 | Khaleed        |   0.39%   |  51.93%  |    0.05% |        Gloo,Hanzo,Uranus,Zilong,Kaja        |
# |      31 | Moskov         |   2.20%   |  51.82%  |    1.08% |        Hanzo,Gloo,Novaria,Argus,Alice       |
# |      12 | Bruno          |   0.59%   |  51.76%  |    0.06% |       Wanwan,Masha,Balmond,Badang,Kaja      |
# |      39 | Roger          |   3.92%   |  51.72%  |   50.14% |    Silvanna,Pharsa,Gatotkaca,Uranus,Saber   |
# |       7 | Alucard        |   1.11%   |  51.63%  |    0.85% |        Natalia,Hanzo,Nolan,Harith,Yve       |
# |     114 | Melissa        |   0.59%   |  51.55%  |    0.25% |     Fredrinn,Alucard,Argus,Estes,Jawhead    |
# |      60 | Hanabi         |   0.84%   |  51.47%  |    0.20% |  Baxia,Faramis,Popol and Kupa,Sun,Mathilda  |
# |     118 | Joy            |   0.31%   |  51.47%  |    0.37% |      Hanzo,Lapu-Lapu,Gord,X.Borg,Lolita     |
# |     107 | Natan          |   0.60%   |  51.42%  |    0.21% |      Gloo,Esmeralda,Balmond,Baxia,Alice     |
# |       4 | Alice          |   0.13%   |  51.16%  |    0.08% |   Esmeralda,Zilong,Khufra,Guinevere,Odette  |
# |      92 | Carmilla       |   0.98%   |  50.96%  |    3.07% | Popol and Kupa,Eudora,Franco,Zilong,Johnson |
# |     101 | Yve            |   0.12%   |  50.96%  |    0.04% |        Granger,Valir,Uranus,Joy,Hilda       |
# |      43 | Irithel        |   0.31%   |  50.87%  |    0.02% |         Aulus,Gord,Yve,Faramis,Hanzo        |
# |      27 | Sun            |   0.73%   |  50.64%  |    1.73% |      Masha,Jawhead,Saber,Lesley,Diggie      |
# |      46 | Odette         |   0.47%   |  50.60%  |    0.07% |       Balmond,Aamon,Rafaela,Joy,Karina      |
# |      68 | Lunox          |   1.00%   |  50.52%  |    1.01% |         Joy,Baxia,Natalia,Hanzo,Gloo        |
# |     102 | Mathilda       |   0.63%   |  50.38%  |    4.88% |       Atlas,Belerick,Hylos,X.Borg,Vale      |
# |      19 | Minotaur       |   1.06%   |  50.35%  |    1.88% |     Johnson,Uranus,Odette,Khufra,Rafaela    |
# |      91 | Cecilion       |   0.89%   |  50.32%  |    0.12% |      Balmond,Aulus,Cyclops,Yve,Rafaela      |
# |     109 | Aamon          |   0.43%   |  50.05%  |    0.43% |        Grock,Ling,Zilong,Masha,Arlott       |
# |     104 | Gloo           |   0.14%   |  50.04%  |    0.08% |        Cyclops,Pharsa,Yve,Baxia,Kaja        |
# |     106 | Phoveus        |   0.63%   |  50.00%  |    5.45% |     Khaleed,Badang,Wanwan,Arlott,Karina     |
# |      64 | Aldous         |   0.25%   |  49.99%  |    0.09% |      Uranus,Balmond,Natalia,Nolan,Gord      |
# |      96 | Luo Yi         |   0.53%   |  49.77%  |    0.31% |       Uranus,Estes,Alice,Fredrinn,Kaja      |
# |     100 | Brody          |   0.87%   |  49.76%  |    0.10% |      Baxia,Aulus,Harley,Natalia,Balmond     |
# |      42 | Harley         |   0.63%   |  49.74%  |    1.07% |       Alice,Hanzo,Rafaela,Wanwan,Grock      |
# |      14 | Rafaela        |   0.18%   |  49.59%  |    0.10% |        Badang,Natalia,Zilong,Akai,Yve       |
# |     116 | Julian         |   2.20%   |  49.53%  |   57.68% |      Aulus,Esmeralda,Sun,Floryn,Uranus      |
# |      24 | Natalia        |   0.27%   |  49.47%  |    0.93% |       Hanzo,Alice,Xavier,Ixia,Beatrix       |
# |     115 | Xavier         |   1.88%   |  49.46%  |    1.89% |     Baxia,Uranus,Barats,Belerick,Balmond    |
# |      86 | Lylia          |   0.80%   |  49.39%  |    0.13% |      Barats,Uranus,Vale,Belerick,Alpha      |
# |      97 | Benedetta      |   0.90%   |  49.32%  |    0.35% |         Hanzo,Alice,Gord,X.Borg,Gloo        |
# |      28 | Alpha          |   1.67%   |  49.31%  |    0.54% |    Uranus,Hilda,Phoveus,Alucard,Fredrinn    |
# |     117 | Fredrinn       |   0.29%   |  49.20%  |    0.14% |      Jawhead,Leomord,Eudora,Kaja,Badang     |
# |      78 | Khufra         |   1.19%   |  49.17%  |    1.02% |   Leomord,Guinevere,Wanwan,Valentina,Saber  |
# |      25 | Kagura         |   1.00%   |  49.15%  |    0.19% |       Gord,Kadita,Estes,Vale,Silvanna       |
# |      13 | Clint          |   1.31%   |  49.09%  |    0.36% |      Karina,Kimmy,Bruno,Odette,Faramis      |
# |      74 | Minsitthar     |   0.49%   |  49.08%  |    0.71% |     Phoveus,Silvanna,Harith,Grock,Roger     |
# |      23 | Gord           |   0.23%   |  49.03%  |    0.04% |     Baxia,Vale,Luo Yi,Minsitthar,Leomord    |
# |     120 | Arlott         |   0.80%   |  48.97%  |    0.40% |     Kaja,Paquito,Esmeralda,Wanwan,X.Borg    |
# |      62 | Kaja           |   0.14%   |  48.90%  |    0.06% |     Martis,Zhuxin,Grock,Silvanna,Melissa    |
# |      84 | Ling           |   1.46%   |  48.85%  |   86.84% |         Hanzo,Gord,Balmond,Yve,Atlas        |
# |      21 | Hayabusa       |   1.16%   |  48.77%  |   90.33% |      Hanzo,Granger,Aamon,Cecilion,Valir     |
# |      99 | Barats         |   0.22%   |  48.73%  |    0.14% |     Eudora,Miya,Cyclops,Guinevere,Wanwan    |
# |      15 | Eudora         |   0.57%   |  48.73%  |    0.66% |        Natalia,Alice,Joy,Zilong,Freya       |
# |      66 | Vale           |   0.32%   |  48.67%  |    0.04% |       Aulus,Masha,Odette,Zilong,Eudora      |
# |      65 | Claude         |   1.77%   |  48.66%  |    0.27% |       Pharsa,Gord,Melissa,Aulus,Lolita      |
# |     123 | Cici           |   0.45%   |  48.55%  |    0.20% |     Hylos,Minsitthar,Yve,Irithel,Novaria    |
# |     113 | Yin            |   0.55%   |  48.55%  |    2.72% |      Hanzo,Zilong,Hanabi,Lolita,Aurora      |
# |      67 | Leomord        |   0.28%   |  48.50%  |    0.05% |       Irithel,Rafaela,Akai,Aulus,Vale       |
# |     122 | Nolan          |   0.59%   |  48.43%  |    0.74% |     Balmond,Floryn,Wanwan,Rafaela,Diggie    |
# |      51 | Helcurt        |   0.92%   |  48.37%  |   32.78% |         Hanzo,Layla,Gord,Gloo,Kimmy         |
# |      95 | Yu Zhong       |   1.67%   |  48.33%  |    0.94% |     Gloo,Esmeralda,Alpha,Rafaela,Lesley     |
# |     119 | Novaria        |   0.51%   |  48.31%  |    0.11% |       Leomord,Alice,Uranus,Hanzo,Ixia       |
# |      61 | Chang'e        |   1.07%   |  48.27%  |    0.26% |        Aulus,Masha,Diggie,Gord,Hanzo        |
# |       3 | Saber          |   0.76%   |  47.98%  |   35.93% |     Hanzo,Nolan,Natalia,Kimmy,Benedetta     |
# |      79 | Granger        |   0.48%   |  47.85%  |    0.06% |        Kaja,Balmond,Alice,Joy,Pharsa        |
# |     108 | Aulus          |   0.09%   |  47.75%  |    0.03% |    Wanwan,Yi Sun-shin,Alice,Aldous,Kadita   |
# |      35 | Hilda          |   0.16%   |  47.75%  |    0.05% |      Novaria,Arlott,Kaja,Vale,Fredrinn      |
# |      89 | Wanwan         |   0.14%   |  47.70%  |    0.03% |      Gord,Martis,Alice,Balmond,Carmilla     |
# |      18 | Layla          |   0.69%   |  47.67%  |    0.63% |       Bruno,Brody,Luo Yi,Zhuxin,Diggie      |
# |      33 | Cyclops        |   0.26%   |  47.56%  |    0.04% |   Jawhead,Benedetta,Badang,Selena,Natalia   |
# |      72 | Thamuz         |   0.37%   |  47.56%  |    0.06% |        Aulus,Hilda,Karina,Paquito,Yin       |
# |       9 | Akai           |   0.33%   |  47.46%  |    0.15% |     Silvanna,Cyclops,Natan,Karina,Barats    |
# |      77 | Badang         |   0.16%   |  47.46%  |    0.02% |       Zilong,Aldous,Hilda,Kadita,Fanny      |
# |      90 | Silvanna       |   0.28%   |  47.44%  |    0.03% |    Eudora,Lapu-Lapu,Selena,Dyrroth,Aamon    |
# |      70 | Belerick       |   0.58%   |  47.28%  |    1.76% |       Wanwan,Miya,Yve,Guinevere,Eudora      |
# |      75 | Kadita         |   0.41%   |  46.83%  |    0.06% |         Pharsa,Yve,Lolita,Aamon,Ixia        |
# |      83 | X.Borg         |   1.16%   |  46.82%  |    0.45% |      Balmond,Martis,Hylos,Barats,Thamuz     |
# |      26 | Chou           |   1.12%   |  46.78%  |    0.39% |       Hanzo,Baxia,Nolan,Fanny,Johnson       |
# |      57 | Valir          |   0.57%   |  46.76%  |    0.30% |     Fredrinn,Uranus,Alucard,Hylos,Badang    |
# |     105 | Beatrix        |   0.59%   |  46.74%  |    0.04% |         Melissa,Miya,Ixia,Yve,Barats        |
# |      54 | Jawhead        |   0.26%   |  46.64%  |    0.04% |        Balmond,Kaja,Eudora,Nolan,Joy        |
# |      69 | Hanzo          |   0.16%   |  46.62%  |    0.22% |         Yve,Grock,Baxia,Diggie,Bane         |
# |       6 | Tigreal        |   2.46%   |  46.45%  |   12.39% |      Freya,Alucard,Zilong,Eudora,Franco     |
# |      59 | Uranus         |   0.14%   |  46.45%  |    0.06% |       Granger,Pharsa,Masha,Gloo,Saber       |
# |     110 | Valentina      |   1.13%   |  46.44%  |    0.53% |       Carmilla,Atlas,Kimmy,X.Borg,Vale      |
# |      58 | Martis         |   0.63%   |  46.44%  |    0.41% |       Eudora,Kadita,Yin,Hilda,Cyclops       |
# |      53 | Lesley         |   1.50%   |  46.43%  |    0.44% |       Belerick,Claude,Cici,Yin,Phoveus      |
# |      93 | Atlas          |   0.52%   |  46.27%  |    0.49% |       Jawhead,Balmond,Layla,Estes,Vale      |
# |      71 | Kimmy          |   0.32%   |  46.13%  |    0.06% |      Yve,Balmond,Kadita,Guinevere,Grock     |
# |      16 | Zilong         |   0.32%   |  45.95%  |    0.24% |        Yve,X.Borg,Hanzo,Fanny,Angela        |
# |      34 | Estes          |   0.32%   |  45.70%  |    2.45% |       Aldous,Cici,Yve,Esmeralda,Hilda       |
# |      52 | Pharsa         |   0.27%   |  45.68%  |    0.08% |      Balmond,Alucard,Bruno,Layla,Luo Yi     |
# |      44 | Grock          |   0.33%   |  45.68%  |    0.06% |      Baxia,X.Borg,Lolita,Lapu-Lapu,Vale     |
# |      17 | Fanny          |   1.37%   |  45.54%  |   30.42% |        Yve,Hanabi,Gloo,Lolita,Wanwan        |
# |      56 | Gusion         |   0.62%   |  45.20%  |    0.16% |        Kaja,Cici,Hanzo,Alpha,Natalia        |
# |      80 | Guinevere      |   0.28%   |  45.20%  |    0.03% |        Kaja,Freya,Gloo,Odette,Uranus        |
# |      63 | Selena         |   0.45%   |  45.14%  |    0.18% |       Balmond,Kaja,Khaleed,Aamon,Grock      |
# |      10 | Franco         |   1.36%   |  45.13%  |    3.21% |     Diggie,Angela,Fanny,Nolan,Valentina     |
# |      85 | Dyrroth        |   0.64%   |  45.05%  |    0.26% |       Baxia,Karina,Uranus,Aldous,Alice      |
# |      37 | Lapu-Lapu      |   0.39%   |  44.66%  |    0.02% |       Gloo,Balmond,Jawhead,Zilong,Cici      |
# |      87 | Baxia          |   0.06%   |  44.51%  |    0.02% |    Balmond,Yve,Rafaela,Leomord,Guinevere    |
# |      40 | Karrie         |   1.28%   |  44.40%  |    0.35% |       Aulus,Hylos,Baxia,Leomord,Barats      |
# |       5 | Nana           |   0.97%   |  44.36%  |    0.99% |        Wanwan,Odette,Kaja,Saber,Freya       |
# |      32 | Johnson        |   0.40%   |  44.27%  |    0.34% |     Masha,Eudora,Guinevere,Hilda,Diggie     |
# |       8 | Karina         |   0.36%   |  44.21%  |    0.26% |      Wanwan,Natalia,Hanzo,Balmond,Ling      |
# |     103 | Paquito        |   0.52%   |  43.17%  |    0.06% |        Alice,Karina,Gloo,Hanabi,Nolan       |
# |      47 | Lancelot       |   1.04%   |  42.35%  |    0.32% |       Baxia,Atlas,Johnson,Gloo,Lolita       |
# |      81 | Esmeralda      |   0.36%   |  40.55%  |    0.35% |      Lolita,Aldous,Hilda,Hanzo,Mathilda     |
# |       2 | Balmond        |   0.10%   |  37.43%  |    0.09% |       Vale,Aulus,Masha,Fredrinn,Eudora      |
# +---------+----------------+-----------+----------+----------+---------------------------------------------+

# %% [markdown]
# ## hero best with, strong against, weak against

# %%
class HeroFilterAPI:
    def __init__(self, url: str, payload: Dict):
        self.url = url
        self.payload = payload

    def fetch_data(self) -> Optional[Dict]:
        try:
            response = requests.post(self.url, json=self.payload)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            print(f"An error occurred: {e}")
            return None

class HeroFilterFactory:
    @staticmethod
    def hero_create_filter(sortid_values: List[int], roadsort_values: List[int], page_size: int, page_index: int, sorts_field: str, sorts_order: str) -> FilterAPI:
        """
        Create a FilterAPI object based on the provided filter parameters.
        Args:
          sortid_values: List of integers representing sort IDs.
          roadsort_values: List of integers representing roadsort values.
          page_size: 1 - 125
          page_index: 1 - 125
          sorts_field: field name to sort by.
          sorts_order: asc, desc

        Returns:
          FilterAPI object.
        """
        url = "https://api.gms.moontontech.com/api/gms/source/2669606/2681577"

        payload = {
            "pageSize": page_size,
            "filters": [
                {"field": "sortid", "operator": "hasAnyOf", "value": sortid_values},
                {"field": "roadsort", "operator": "hasAnyOf", "value": roadsort_values}
            ],
            "sorts": [{"data": {"field": sorts_field, "order": sorts_order}, "type": "sequence"}],
            "pageIndex": page_index,
            "fields": ["roadsort", "channel", "sortid", "smallmap", "name", "heroid"]
        }

        return FilterAPI(url=url, payload=payload)

def hero_create_hero_table(data: Dict) -> PrettyTable:
    table = PrettyTable()
    table.field_names = [
        "Hero ID",
        "Hero Name",
        "Best With",
        "Strong Against",
        "Weak Against",
        "Desc Best With",
        "Desc Strong Against",
        "Desc Weak Against",
    ]
    table.align["Hero ID"] = "r"
    table.align["Hero Name"] = "l"

    table.align["Desc Best With"] = "l"
    table.align["Desc Strong Against"] = "l"
    table.align["Desc Weak Against"] = "l"
    table.right_padding_width = 1

    hero_name_dict = {
        125: "Zhuxin",
        124: "Chip",
        123: "Cici",
        122: "Nolan",
        121: "Ixia",
        120: "Arlott",
        119: "Novaria",
        118: "Joy",
        117: "Fredrinn",
        116: "Julian",
        115: "Xavier",
        114: "Melissa",
        113: "Yin",
        112: "Floryn",
        111: "Edith",
        110: "Valentina",
        109: "Aamon",
        108: "Aulus",
        107: "Natan",
        106: "Phoveus",
        105: "Beatrix",
        104: "Gloo",
        103: "Paquito",
        102: "Mathilda",
        101: "Yve",
        100: "Brody",
        99: "Barats",
        98: "Khaleed",
        97: "Benedetta",
        96: "Luo Yi",
        95: "Yu Zhong",
        94: "Popol and Kupa",
        93: "Atlas",
        92: "Carmilla",
        91: "Cecilion",
        90: "Silvanna",
        89: "Wanwan",
        88: "Masha",
        87: "Baxia",
        86: "Lylia",
        85: "Dyrroth",
        84: "Ling",
        83: "X.Borg",
        82: "Terizla",
        81: "Esmeralda",
        80: "Guinevere",
        79: "Granger",
        78: "Khufra",
        77: "Badang",
        76: "Faramis",
        75: "Kadita",
        74: "Minsitthar",
        73: "Harith",
        72: "Thamuz",
        71: "Kimmy",
        70: "Belerick",
        69: "Hanzo",
        68: "Lunox",
        67: "Leomord",
        66: "Vale",
        65: "Claude",
        64: "Aldous",
        63: "Selena",
        62: "Kaja",
        61: "Chang'e",
        60: "Hanabi",
        59: "Uranus",
        58: "Martis",
        57: "Valir",
        56: "Gusion",
        55: "Angela",
        54: "Jawhead",
        53: "Lesley",
        52: "Pharsa",
        51: "Helcurt",
        50: "Zhask",
        49: "Hylos",
        48: "Diggie",
        47: "Lancelot",
        46: "Odette",
        45: "Argus",
        44: "Grock",
        43: "Irithel",
        42: "Harley",
        41: "Gatotkaca",
        40: "Karrie",
        39: "Roger",
        38: "Vexana",
        37: "Lapu-Lapu",
        36: "Aurora",
        35: "Hilda",
        34: "Estes",
        33: "Cyclops",
        32: "Johnson",
        31: "Moskov",
        30: "Yi Sun-shin",
        29: "Ruby",
        28: "Alpha",
        27: "Sun",
        26: "Chou",
        25: "Kagura",
        24: "Natalia",
        23: "Gord",
        22: "Freya",
        21: "Hayabusa",
        20: "Lolita",
        19: "Minotaur",
        18: "Layla",
        17: "Fanny",
        16: "Zilong",
        15: "Eudora",
        14: "Rafaela",
        13: "Clint",
        12: "Bruno",
        11: "Bane",
        10: "Franco",
        9: "Akai",
        8: "Karina",
        7: "Alucard",
        6: "Tigreal",
        5: "Nana",
        4: "Alice",
        3: "Saber",
        2: "Balmond",
        1: "Miya"
    }

    # print(hero_name_dict)

    for record in data['data']['records']:
        hero_data = record['data']
        relation = hero_data['channel']['data']['relation']

        strong_against = ', '.join([hero_name_dict.get(hero_id, "Unknown") for hero_id in relation['strong']['target_hero_id']])
        weak_against = ', '.join([hero_name_dict.get(hero_id, "Unknown") for hero_id in relation['weak']['target_hero_id']])
        best_with = ', '.join([hero_name_dict.get(hero_id, "Unknown") for hero_id in relation['assist']['target_hero_id']])

        desc_strong_against = relation['strong']['desc']
        desc_weak_against = relation['weak']['desc']
        desc_best_with = relation['assist']['desc']

        table.add_row([
            hero_data['heroid'],
            hero_data['name'],
            best_with,
            strong_against,
            weak_against,
            desc_best_with,
            desc_strong_against,
            desc_weak_against,
        ])

    return table

# %%
def hero_main():
    sortid_values          = [1, 2, 3, 4, 5, 6]
    roadsort_values        = [1, 2, 3, 4, 5]
    page_size              = 125
    page_index             = 1
    sorts_field, sorts_order = "heroid", "asc"

    hero_filter_factory = HeroFilterFactory.hero_create_filter(sortid_values, roadsort_values, page_size, page_index, sorts_field, sorts_order)

    data = hero_filter_factory.fetch_data()
    if data:
        table = hero_create_hero_table(data)
        print(table)
    else:
        print("Failed to retrieve data.")

if __name__ == "__main__":
    hero_main()
# Out:
# +---------+----------------+------------------------------+-------------------------------+-------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Hero ID | Hero Name      |          Best With           |         Strong Against        |          Weak Against         | Desc Best With                                                                                                                                                                                                                                                                                     | Desc Strong Against                                                                                                                                                                                                                                                        | Desc Weak Against                                                                                                                                                                                                                                           |
# +---------+----------------+------------------------------+-------------------------------+-------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |       1 | Miya           |      Tigreal, Belerick       |       Saber, Eudora, Sun      |          Pharsa, Yve          | Miya works well with Tanks who have powerful CC abilities like Belerick and Tigreal since their CCs give her more opportunities to dish out damage.                                                                                                                                                | Miya counters heroes who rely on targeted CC effects, such as Saber and Eudora, because she can easily escape their CC and respond with a strong counterattack. The split arrows from her 1st Skill are also very effective against heroes that summon units, such as Sun. | Miya is countered by heroes with a lot of AOE damage, such as Pharsa and Yve, because they can still hit her while she is concealed.                                                                                                                        |
# |       2 | Balmond        |       Angela, Rafaela        |         Layla, Eudora         |        Lesley, Irithel        | Balmond is best with Support heroes that can boost his Mobility and Survivability. Examples include Angela and Rafaela.                                                                                                                                                                            | Balmond is strong against squishy heroes who lack the ability to escape once he closes the gap on them, such as Layla and Eudora.                                                                                                                                          | Balmond is countered by ranged heroes who can deal damage to Balmond outside of his attack range, such as Lesley and Irithel.                                                                                                                               |
# |       3 | Saber          |       Kadita, Cyclops        |         Layla, Eudora         |         Estes, Faramis        | Saber works well with high-damage heroes who can help him burst down enemy heroes in teamfights, such as Kadita and Cyclops.                                                                                                                                                                       | Saber's deadly combo makes him strong against squishy heroes, such as Layla and Eudora.                                                                                                                                                                                    | Saber is countered by Support heroes with Survivability buffs, like Estes and Faramis.                                                                                                                                                                      |
# |       4 | Alice          |       Balmond, Dyrroth       |       Cecilion, Chang'e       |         Baxia, Martis         | To compensate for Alice's weaknesses in the early game and form a balanced team, pair her with strong early game heroes, like Balmond or Dyrroth.                                                                                                                                                  | With her great sustainability in combat plus her mobility and CC, Alice counters heroes that lack burst and can't escape from melee enemies, such as Cecilion and Chang'e.                                                                                                 | Alice is countered by heroes with Execute or Healing Reduction who can impede her from healing herself during the Ultimate. Heroes like Baxia or Martis can reduce her healing or kill her before she can heal.                                             |
# |       5 | Nana           |       Rafaela, Franco        |         Eudora, Kadita        |        Zilong, Natalia        | Nana works best with heroes with CC skills, that will help her get the kills, such as Rafaela and Franco.                                                                                                                                                                                          | Nana's Passive gives her great survivability, making her strong against heroes with deadly combos, like Eudora and Kadita.                                                                                                                                                 | Nana can be countered by heroes with strong chasing abilities, like Zilong, Natalia, because they can chase Nana through her Passive duration.                                                                                                              |
------------------------+-------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## hero detail

# %%
class HeroData:
    HERO_NAME_DICT = {
        125: "Zhuxin", 124: "Chip", 123: "Cici", 122: "Nolan", 121: "Ixia", 120: "Arlott", 119: "Novaria",
        118: "Joy", 117: "Fredrinn", 116: "Julian", 115: "Xavier", 114: "Melissa", 113: "Yin", 112: "Floryn",
        111: "Edith", 110: "Valentina", 109: "Aamon", 108: "Aulus", 107: "Natan", 106: "Phoveus", 105: "Beatrix",
        104: "Gloo", 103: "Paquito", 102: "Mathilda", 101: "Yve", 100: "Brody", 99: "Barats", 98: "Khaleed",
        97: "Benedetta", 96: "Luo Yi", 95: "Yu Zhong", 94: "Popol and Kupa", 93: "Atlas", 92: "Carmilla",
        91: "Cecilion", 90: "Silvanna", 89: "Wanwan", 88: "Masha", 87: "Baxia", 86: "Lylia", 85: "Dyrroth",
        84: "Ling", 83: "X.Borg", 82: "Terizla", 81: "Esmeralda", 80: "Guinevere", 79: "Granger", 78: "Khufra",
        77: "Badang", 76: "Faramis", 75: "Kadita", 74: "Minsitthar", 73: "Harith", 72: "Thamuz", 71: "Kimmy",
        70: "Belerick", 69: "Hanzo", 68: "Lunox", 67: "Leomord", 66: "Vale", 65: "Claude", 64: "Aldous",
        63: "Selena", 62: "Kaja", 61: "Chang'e", 60: "Hanabi", 59: "Uranus", 58: "Martis", 57: "Valir",
        56: "Gusion", 55: "Angela", 54: "Jawhead", 53: "Lesley", 52: "Pharsa", 51: "Helcurt", 50: "Zhask",
        49: "Hylos", 48: "Diggie", 47: "Lancelot", 46: "Odette", 45: "Argus", 44: "Grock", 43: "Irithel",
        42: "Harley", 41: "Gatotkaca", 40: "Karrie", 39: "Roger", 38: "Vexana", 37: "Lapu-Lapu", 36: "Aurora",
        35: "Hilda", 34: "Estes", 33: "Cyclops", 32: "Johnson", 31: "Moskov", 30: "Yi Sun-shin", 29: "Ruby",
        28: "Alpha", 27: "Sun", 26: "Chou", 25: "Kagura", 24: "Natalia", 23: "Gord", 22: "Freya", 21: "Hayabusa",
        20: "Lolita", 19: "Minotaur", 18: "Layla", 17: "Fanny", 16: "Zilong", 15: "Eudora", 14: "Rafaela",
        13: "Clint", 12: "Bruno", 11: "Bane", 10: "Franco", 9: "Akai", 8: "Karina", 7: "Alucard", 6: "Tigreal",
        5: "Nana", 4: "Alice", 3: "Saber", 2: "Balmond", 1: "Miya"
    }

    def __init__(self, url, payload):
        self.url = url
        self.payload = payload
        self.data = None

    def fetch_data(self):
        response = requests.post(self.url, json=self.payload)
        response.raise_for_status()
        self.data = response.json()

    def display_table(self, title, rows, field_names):
        table = PrettyTable()
        table.field_names = field_names
        for row in rows:
            table.add_row(row)
        print(f"\n{title}:")
        print(table)

    def display_main_hero(self):
        main_hero_data = self.data["data"]["records"][0]["data"]["main_hero"]["data"]
        main_hero = self.data['data']['records'][0]['data']
        main_hero_channel = self.data['data']['records'][0]['data']['main_hero_channel']

        rows = [
            # ["Image URL", main_hero_data["head"]],
            ["Hero ID", main_hero["main_heroid"]],
            ["Hero Name", main_hero_data["name"]],
            # ["Channel ID", main_hero_channel["id"]],
            # ["Match Type", main_hero["match_type"]],
            # ["Big Rank", main_hero["bigrank"]],
            # ["Camp Type", main_hero["camp_type"]],
            ["Pick Rate", f'{main_hero["main_hero_appearance_rate"] * 100:.2f}%'],
            ["Ban Rate", f'{main_hero["main_hero_ban_rate"] * 100:.2f}%'],
            ["Win Rate", f'{main_hero["main_hero_win_rate"] * 100:.2f}%'],
        ]
        self.display_table("Main Hero Information", rows, ["Attribute", "Value"])

    # counter relationship
    def display_sub_heroes_counter_relationship(self):
        sub_heroes = self.data["data"]["records"][0]["data"]["sub_hero"]
        rows = []
        for hero in sub_heroes:
            hero_name = self.HERO_NAME_DICT.get(hero["heroid"], "Unknown")
            row = [
                # hero["hero"]["data"]["head"],
                hero["hero_index"],
                # hero["hero_channel"]["id"],
                hero_name,
                f'{hero["increase_win_rate"] * 100:.2f}',
                f'{hero["hero_appearance_rate"] * 100:.2f}%',
                f'{hero["hero_win_rate"] * 100:.2f}%',
                f'{hero["min_win_rate10_12"] * 100:.2f}%',
                f'{hero["min_win_rate12_14"] * 100:.2f}%',
                f'{hero["min_win_rate14_16"] * 100:.2f}%',
                f'{hero["min_win_rate16_18"] * 100:.2f}%',
                f'{hero["min_win_rate18_20"] * 100:.2f}%',
                f'{hero["min_win_rate20"] * 100:.2f}%',
                f'{hero["min_win_rate6"] * 100:.2f}%',
                f'{hero["min_win_rate6_8"] * 100:.2f}%',
                f'{hero["min_win_rate8_10"] * 100:.2f}%'
            ]
            rows.append(row)
        self.display_table("Best Counters", rows, [
            # "Hero Image",
            "Index",
            # "Channel ID",
            "Hero Name",
            "Counter Score",
            "Pick Rate",
            "Win Rate",
            "Win Rate 10-12",
            "Win Rate 12-14",
            "Win Rate 14-16",
            "Win Rate 16-18",
            "Win Rate 18-20",
            "Win Rate 20+",
            "Win Rate 6+",
            "Win Rate 6-8",
            "Win Rate 8-10"
        ])

    def display_last_sub_heroes_counter_relationship(self):
        last_sub_heroes = self.data["data"]["records"][0]["data"]["sub_hero_last"]
        rows = []
        for hero in last_sub_heroes:
            hero_name = self.HERO_NAME_DICT.get(hero["heroid"], "Unknown")
            row = [
                hero["hero_index"],
                hero_name,
                f'{hero["increase_win_rate"] * 100:.2f}',
                f'{hero["hero_appearance_rate"] * 100:.2f}%',
                f'{hero["hero_win_rate"] * 100:.2f}%',
                f'{hero["min_win_rate10_12"] * 100:.2f}%',
                f'{hero["min_win_rate12_14"] * 100:.2f}%',
                f'{hero["min_win_rate14_16"] * 100:.2f}%',
                f'{hero["min_win_rate16_18"] * 100:.2f}%',
                f'{hero["min_win_rate18_20"] * 100:.2f}%',
                f'{hero["min_win_rate20"] * 100:.2f}%',
                f'{hero["min_win_rate6"] * 100:.2f}%',
                f'{hero["min_win_rate6_8"] * 100:.2f}%',
                f'{hero["min_win_rate8_10"] * 100:.2f}%'
            ]
            rows.append(row)
        self.display_table("Most Countered by", rows, [
            "Index",
            "Hero Name",
            "Counter Score",
            "Pick Rate",
            "Win Rate",
            "Win Rate 10-12",
            "Win Rate 12-14",
            "Win Rate 14-16",
            "Win Rate 16-18",
            "Win Rate 18-20",
            "Win Rate 20+",
            "Win Rate 6+",
            "Win Rate 6-8",
            "Win Rate 8-10"
        ])

    # compatibility
    def display_sub_heroes_compatibility(self):
        sub_heroes = self.data["data"]["records"][0]["data"]["sub_hero"]
        rows = []
        for hero in sub_heroes:
            hero_name = self.HERO_NAME_DICT.get(hero["heroid"], "Unknown")
            row = [
                # hero["hero"]["data"]["head"],
                hero["hero_index"],
                hero_name,
                f'{hero["increase_win_rate"] * 100:.2f}',
                f'{hero["hero_appearance_rate"] * 100:.2f}%',
                # hero["hero_channel"]["id"],
                f'{hero["hero_win_rate"] * 100:.2f}%',
                f'{hero["min_win_rate10_12"] * 100:.2f}%',
                f'{hero["min_win_rate12_14"] * 100:.2f}%',
                f'{hero["min_win_rate14_16"] * 100:.2f}%',
                f'{hero["min_win_rate16_18"] * 100:.2f}%',
                f'{hero["min_win_rate18_20"] * 100:.2f}%',
                f'{hero["min_win_rate20"] * 100:.2f}%',
                f'{hero["min_win_rate6"] * 100:.2f}%',
                f'{hero["min_win_rate6_8"] * 100:.2f}%',
                f'{hero["min_win_rate8_10"] * 100:.2f}%'
            ]
            rows.append(row)
        self.display_table("Compatibility", rows, [
            # "Hero Image",
            "Index",
            "Hero Name",
            "Teammate Score",
            "Pick Rate",
            # "Channel ID",
            "Win Rate",
            "Win Rate 10-12",
            "Win Rate 12-14",
            "Win Rate 14-16",
            "Win Rate 16-18",
            "Win Rate 18-20",
            "Win Rate 20+",
            "Win Rate 6+",
            "Win Rate 6-8",
            "Win Rate 8-10"
        ])

    def display_last_sub_heroes_compatibility(self):
        last_sub_heroes = self.data["data"]["records"][0]["data"]["sub_hero_last"]
        rows = []
        for hero in last_sub_heroes:
            hero_name = self.HERO_NAME_DICT.get(hero["heroid"], "Unknown")
            row = [
                hero["hero_index"],
                hero_name,
                f'{hero["increase_win_rate"] * 100:.2f}',
                f'{hero["hero_appearance_rate"] * 100:.2f}%',
                f'{hero["hero_win_rate"] * 100:.2f}%',
                f'{hero["min_win_rate10_12"] * 100:.2f}%',
                f'{hero["min_win_rate12_14"] * 100:.2f}%',
                f'{hero["min_win_rate14_16"] * 100:.2f}%',
                f'{hero["min_win_rate16_18"] * 100:.2f}%',
                f'{hero["min_win_rate18_20"] * 100:.2f}%',
                f'{hero["min_win_rate20"] * 100:.2f}%',
                f'{hero["min_win_rate6"] * 100:.2f}%',
                f'{hero["min_win_rate6_8"] * 100:.2f}%',
                f'{hero["min_win_rate8_10"] * 100:.2f}%'
            ]
            rows.append(row)
        self.display_table("Not Compatible", rows, [
            "Index",
            "Hero Name",
            "Teammate Score",
            "Pick Rate",
            "Win Rate",
            "Win Rate 10-12",
            "Win Rate 12-14",
            "Win Rate 14-16",
            "Win Rate 16-18",
            "Win Rate 18-20",
            "Win Rate 20+",
            "Win Rate 6+",
            "Win Rate 6-8",
            "Win Rate 8-10"
        ])

# %%
url = "https://api.gms.moontontech.com/api/gms/source/2669606/2690519"
payload = {
    "pageSize": 20,
    "filters": [
        {"field": "main_heroid", "operator": "eq", "value": 84},
        {"field": "bigrank", "operator": "eq", "value": "7"},
        {"field": "match_type", "operator": "eq", "value": "0"}
    ],
    "sorts": [],
    "pageIndex": 1
}

hero_data = HeroData(url, payload)

hero_data.fetch_data()

hero_data.display_main_hero()
hero_data.display_sub_heroes_counter_relationship()
hero_data.display_last_sub_heroes_counter_relationship()

# ============================================================

payload = {
    "pageSize": 20,
    "filters": [
        {"field": "main_heroid", "operator": "eq", "value": 84},
        {"field": "bigrank", "operator": "eq", "value": "7"},
        {"field": "match_type", "operator": "eq", "value": "1"}
    ],
    "sorts": [],
    "pageIndex": 1
}

hero_data = HeroData(url, payload)

hero_data.fetch_data()

hero_data.display_sub_heroes_compatibility()
hero_data.display_last_sub_heroes_compatibility()
# Out:
# Main Hero Information:
# +-----------+--------+
# | Attribute | Value  |
# +-----------+--------+
# |  Hero ID  |   84   |
# | Hero Name |  Ling  |
# | Pick Rate | 0.86%  |
# |  Ban Rate | 76.52% |
# |  Win Rate | 49.38% |
# +-----------+--------+
#
# Best Counters:
# +-------+-----------+---------------+-----------+----------+----------------+----------------+----------------+----------------+----------------+--------------+-------------+--------------+---------------+
# | Index | Hero Name | Counter Score | Pick Rate | Win Rate | Win Rate 10-12 | Win Rate 12-14 | Win Rate 14-16 | Win Rate 16-18 | Win Rate 18-20 | Win Rate 20+ | Win Rate 6+ | Win Rate 6-8 | Win Rate 8-10 |
# +-------+-----------+---------------+-----------+----------+----------------+----------------+----------------+----------------+----------------+--------------+-------------+--------------+---------------+
# |   1   |   Hanzo   |      4.95     |   0.28%   |  46.15%  |     59.06%     |     57.81%     |     58.09%     |     58.13%     |     57.89%     |    57.03%    |   100.00%   |    82.29%    |     67.22%    |
# |   2   |    Gloo   |      3.64     |   0.09%   |  52.67%  |     41.24%     |     48.28%     |     47.75%     |     52.58%     |     54.36%     |    55.26%    |   100.00%   |    56.76%    |     41.23%    |
# |   3   |   Atlas   |      2.98     |   0.64%   |  49.81%  |     47.75%     |     51.02%     |     52.01%     |     53.95%     |     55.56%     |    55.24%    |    50.00%   |    56.42%    |     48.11%    |
# |   4   |    Gord   |      2.93     |   0.36%   |  50.09%  |     45.27%     |     49.76%     |     51.77%     |     53.57%     |     55.93%     |    54.93%    |   100.00%   |    61.99%    |     44.54%    |
# |   5   |   Kimmy   |      2.89     |   0.47%   |  47.73%  |     55.32%     |     56.00%     |     55.53%     |     54.60%     |     52.67%     |    52.49%    |    75.00%   |    64.56%    |     59.09%    |
# +-------+-----------+---------------+-----------+----------+----------------+----------------+----------------+----------------+----------------+--------------+-------------+--------------+---------------+
#
# Most Countered by:
# +-------+-----------+---------------+-----------+----------+----------------+----------------+----------------+----------------+----------------+--------------+-------------+--------------+---------------+
# | Index | Hero Name | Counter Score | Pick Rate | Win Rate | Win Rate 10-12 | Win Rate 12-14 | Win Rate 14-16 | Win Rate 16-18 | Win Rate 18-20 | Win Rate 20+ | Win Rate 6+ | Win Rate 6-8 | Win Rate 8-10 |
# +-------+-----------+---------------+-----------+----------+----------------+----------------+----------------+----------------+----------------+--------------+-------------+--------------+---------------+
# |   1   |  Natalia  |     -3.50     |   0.62%   |  48.60%  |     46.89%     |     47.43%     |     47.40%     |     47.17%     |     47.45%     |    47.33%    |   100.00%   |    37.43%    |     46.89%    |
# |   2   |  Cyclops  |     -3.06     |   0.55%   |  49.46%  |     42.81%     |     45.51%     |     45.92%     |     47.91%     |     48.26%     |    50.90%    |    50.00%   |    55.11%    |     44.15%    |
